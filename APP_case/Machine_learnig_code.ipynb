# %% [markdown]
# # APP purchasing prediction with TensorFlow. Part 2

# %% [markdown]
# # Machine learning

# %% [markdown]
# Code Created by Luis Enrique Acevedo Galicia
#
# Date: 2019-24-02
#
# Here, I present a simple and easy way to create a machine learning algorithm, which is able to predict if a customer will buy again.
#
# Data comes from the preprocessing script. Here a net with 3 hidden layers is presented to predict if a customer will buy again.

# %% [markdown]
# # The Libraries

# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# # Batch data

# %%
#Divide all data in batches
class Batch_data_reader():
    def __init__(self,DataSet, size_batch = None):
        npz = np.load('APP_data_{0}.npz'.format(DataSet))
        self.inputs = npz['inputs'].astype(np.float)
        self.targets = npz['targets'].astype(np.int)
        #count the batch
        if size_batch is None:
            self.size_batch = self.inputs.shape[0]
        else:
            self.size_batch = size_batch
        self.batch_current = 0
        self.batch_count = self.inputs.shape[0]//self.size_batch
    #load next batch
    def __next__(self):
        if self.batch_current >= self.batch_count:
            self.batch_current = 0
            raise StopIteration()
        slice_batch = slice(self.batch_current*self.size_batch, (self.batch_current+1)*self.size_batch)
        batch_inputs = self.inputs[slice_batch]
        batch_targets = self.targets[slice_batch]
        self.batch_current += 1
        
        #get targets in format [0 1] or [1 0]
        num_c = 2
        targets_def = np.zeros((batch_targets.shape[0],num_c))
        targets_def[range(batch_targets.shape[0]), batch_targets]=1
        
        return batch_inputs, targets_def
    #this part allows the class to iterate 
    def __iter__(self):
        return self

# %% [markdown]
# # Machine learning code

# %%
#define inputs and targets size
input_size = 10
output_size = 2
# hidden layer size
hidden_layer_size = 100

# Reset the default graph
tf.reset_default_graph()

# Placeholders
inputs = tf.placeholder(tf.float32, [None, input_size])
targets = tf.placeholder(tf.int32, [None, output_size])

# The net will contain 3 hidden layers


weights_1 = tf.get_variable("weights_1", [input_size, hidden_layer_size])
biases_1 = tf.get_variable("biases_1", [hidden_layer_size])
outputs_1 = tf.nn.relu(tf.matmul(inputs, weights_1) + biases_1)

weights_2 = tf.get_variable("weights_2", [hidden_layer_size, hidden_layer_size])
biases_2 = tf.get_variable("biases_2", [hidden_layer_size])
outputs_2 = tf.nn.relu(tf.matmul(outputs_1, weights_2) + biases_2)

weights_3 = tf.get_variable("weights_3", [hidden_layer_size, hidden_layer_size])
biases_3 = tf.get_variable("biases_3", [hidden_layer_size])
outputs_3 = tf.nn.sigmoid(tf.matmul(outputs_2, weights_3) + biases_3)

weights_4 = tf.get_variable("weights_4", [hidden_layer_size, output_size])
biases_4 = tf.get_variable("biases_4", [output_size])
# The softmax activation into the loss
outputs = tf.matmul(outputs_3, weights_4) + biases_4



# Use the softmax cross entropy loss with logits
loss = tf.nn.softmax_cross_entropy_with_logits(logits=outputs, labels=targets)
mean_loss = tf.reduce_mean(loss)

# Get a 0 or 1 for every input indicating whether it output the correct answer
out_equals_target = tf.equal(tf.argmax(outputs, 1), tf.argmax(targets, 1))
accuracy = tf.reduce_mean(tf.cast(out_equals_target, tf.float32))

# Optimize with Adam
optimize = tf.train.AdamOptimizer(learning_rate=0.0001).minimize(mean_loss)

# Create a session
sess = tf.InteractiveSession()

# Initialize the variables
initializer = tf.global_variables_initializer()
sess.run(initializer)

# Choose the batch size
batch_size = 100

# Set early stopping mechanisms
max_epochs = 100
prev_validation_loss = 9999999.


train_data = Batch_data_reader('Train', batch_size)
validation_data = Batch_data_reader('Valid')

# Create the loop for epochs 
for epoch_counter in range(max_epochs):
    
    # initialize the epoch loss to 0
    curr_epoch_loss = 0.
    
    # Iterations over the batched training data 
    for input_batch, target_batch in train_data:
        _, batch_loss = sess.run([optimize, mean_loss], 
            feed_dict={inputs: input_batch, targets: target_batch})
        
        #Get record of the batch loss
        curr_epoch_loss += batch_loss
    
    # The mean curr_epoch_loss
    
    curr_epoch_loss /= train_data.batch_count
    
    #Validation:
    
    # Validation loss and accuracy for the epoch to zero
    validation_loss = 0.
    validation_accuracy = 0.
    
    # In this case the batch size is equal to the data set
    
    for input_batch, target_batch in validation_data:
        validation_loss, validation_accuracy = sess.run([mean_loss, accuracy],
            feed_dict={inputs: input_batch, targets: target_batch})
    
    # Print results and statistics for the current epoch
    print('Epoch '+str(epoch_counter+1)+
          '. Training loss: '+'{0:.3f}'.format(curr_epoch_loss)+
          '. Validation loss: '+'{0:.3f}'.format(validation_loss)+
          '. Validation accuracy: '+'{0:.2f}'.format(validation_accuracy * 100.)+'%')
    
    # An early stop (only if validation loss is increasing)
    if validation_loss > prev_validation_loss:
        break
        
    #keep epochs validation loss.
    prev_validation_loss = validation_loss
    
print('End of training.')
# Out:
# Epoch 1. Training loss: 0.929. Validation loss: 0.857. Validation accuracy: 48.77%
# Epoch 2. Training loss: 0.777. Validation loss: 0.735. Validation accuracy: 48.99%
# Epoch 3. Training loss: 0.691. Validation loss: 0.668. Validation accuracy: 55.70%
# Epoch 4. Training loss: 0.646. Validation loss: 0.627. Validation accuracy: 66.89%
# Epoch 5. Training loss: 0.613. Validation loss: 0.594. Validation accuracy: 71.59%
# Epoch 6. Training loss: 0.585. Validation loss: 0.564. Validation accuracy: 73.60%
# Epoch 7. Training loss: 0.559. Validation loss: 0.538. Validation accuracy: 74.27%
# Epoch 8. Training loss: 0.536. Validation loss: 0.515. Validation accuracy: 74.50%
# Epoch 9. Training loss: 0.515. Validation loss: 0.495. Validation accuracy: 75.39%
# Epoch 10. Training loss: 0.497. Validation loss: 0.479. Validation accuracy: 76.06%
# Epoch 11. Training loss: 0.482. Validation loss: 0.464. Validation accuracy: 76.29%
# Epoch 12. Training loss: 0.468. Validation loss: 0.452. Validation accuracy: 77.18%
# Epoch 13. Training loss: 0.456. Validation loss: 0.441. Validation accuracy: 77.63%
# Epoch 14. Training loss: 0.446. Validation loss: 0.432. Validation accuracy: 78.08%
# Epoch 15. Training loss: 0.437. Validation loss: 0.425. Validation accuracy: 78.52%
# Epoch 16. Training loss: 0.429. Validation loss: 0.418. Validation accuracy: 78.75%
# Epoch 17. Training loss: 0.423. Validation loss: 0.412. Validation accuracy: 79.19%
# Epoch 18. Training loss: 0.417. Validation loss: 0.406. Validation accuracy: 79.19%
# Epoch 19. Training loss: 0.411. Validation loss: 0.401. Validation accuracy: 79.87%
# Epoch 20. Training loss: 0.406. Validation loss: 0.397. Validation accuracy: 79.87%
# Epoch 21. Training loss: 0.402. Validation loss: 0.393. Validation accuracy: 80.09%
# Epoch 22. Training loss: 0.398. Validation loss: 0.390. Validation accuracy: 80.31%
# Epoch 23. Training loss: 0.394. Validation loss: 0.386. Validation accuracy: 80.54%
# Epoch 24. Training loss: 0.390. Validation loss: 0.383. Validation accuracy: 80.76%
# Epoch 25. Training loss: 0.387. Validation loss: 0.380. Validation accuracy: 80.98%
# Epoch 26. Training loss: 0.384. Validation loss: 0.378. Validation accuracy: 80.76%
# Epoch 27. Training loss: 0.382. Validation loss: 0.375. Validation accuracy: 80.76%
# Epoch 28. Training loss: 0.379. Validation loss: 0.373. Validation accuracy: 80.98%
# Epoch 29. Training loss: 0.377. Validation loss: 0.371. Validation accuracy: 81.21%
# Epoch 30. Training loss: 0.374. Validation loss: 0.369. Validation accuracy: 81.21%
# Epoch 31. Training loss: 0.372. Validation loss: 0.367. Validation accuracy: 80.98%
# Epoch 32. Training loss: 0.370. Validation loss: 0.365. Validation accuracy: 80.98%
# Epoch 33. Training loss: 0.368. Validation loss: 0.364. Validation accuracy: 80.98%
# Epoch 34. Training loss: 0.367. Validation loss: 0.362. Validation accuracy: 81.21%
# Epoch 35. Training loss: 0.365. Validation loss: 0.360. Validation accuracy: 81.21%
# Epoch 36. Training loss: 0.364. Validation loss: 0.359. Validation accuracy: 81.21%
# Epoch 37. Training loss: 0.362. Validation loss: 0.358. Validation accuracy: 80.98%
# Epoch 38. Training loss: 0.361. Validation loss: 0.356. Validation accuracy: 80.98%
# Epoch 39. Training loss: 0.359. Validation loss: 0.355. Validation accuracy: 80.76%
# Epoch 40. Training loss: 0.358. Validation loss: 0.354. Validation accuracy: 80.76%
# Epoch 41. Training loss: 0.357. Validation loss: 0.353. Validation accuracy: 80.76%
# Epoch 42. Training loss: 0.356. Validation loss: 0.352. Validation accuracy: 80.98%
# Epoch 43. Training loss: 0.355. Validation loss: 0.351. Validation accuracy: 80.98%
# Epoch 44. Training loss: 0.354. Validation loss: 0.350. Validation accuracy: 81.21%
# Epoch 45. Training loss: 0.353. Validation loss: 0.349. Validation accuracy: 81.43%
# Epoch 46. Training loss: 0.352. Validation loss: 0.348. Validation accuracy: 81.21%
# Epoch 47. Training loss: 0.351. Validation loss: 0.347. Validation accuracy: 81.21%
# Epoch 48. Training loss: 0.350. Validation loss: 0.347. Validation accuracy: 81.21%
# Epoch 49. Training loss: 0.349. Validation loss: 0.346. Validation accuracy: 81.66%
# Epoch 50. Training loss: 0.349. Validation loss: 0.345. Validation accuracy: 81.66%
# Epoch 51. Training loss: 0.348. Validation loss: 0.344. Validation accuracy: 81.66%
# Epoch 52. Training loss: 0.347. Validation loss: 0.344. Validation accuracy: 81.88%
# Epoch 53. Training loss: 0.346. Validation loss: 0.343. Validation accuracy: 81.88%
# Epoch 54. Training loss: 0.346. Validation loss: 0.342. Validation accuracy: 82.10%
# Epoch 55. Training loss: 0.345. Validation loss: 0.342. Validation accuracy: 82.10%
# Epoch 56. Training loss: 0.344. Validation loss: 0.341. Validation accuracy: 82.10%
# Epoch 57. Training loss: 0.344. Validation loss: 0.341. Validation accuracy: 82.10%
# Epoch 58. Training loss: 0.343. Validation loss: 0.340. Validation accuracy: 82.10%
# Epoch 59. Training loss: 0.342. Validation loss: 0.340. Validation accuracy: 82.10%
# Epoch 60. Training loss: 0.342. Validation loss: 0.339. Validation accuracy: 82.33%
# Epoch 61. Training loss: 0.341. Validation loss: 0.339. Validation accuracy: 82.33%
# Epoch 62. Training loss: 0.341. Validation loss: 0.338. Validation accuracy: 82.33%
# Epoch 63. Training loss: 0.340. Validation loss: 0.338. Validation accuracy: 82.33%
# Epoch 64. Training loss: 0.340. Validation loss: 0.337. Validation accuracy: 82.33%
# Epoch 65. Training loss: 0.339. Validation loss: 0.337. Validation accuracy: 82.33%
# Epoch 66. Training loss: 0.338. Validation loss: 0.337. Validation accuracy: 82.33%
# Epoch 67. Training loss: 0.338. Validation loss: 0.336. Validation accuracy: 82.33%
# Epoch 68. Training loss: 0.338. Validation loss: 0.336. Validation accuracy: 82.33%
# Epoch 69. Training loss: 0.337. Validation loss: 0.336. Validation accuracy: 82.33%
# Epoch 70. Training loss: 0.337. Validation loss: 0.335. Validation accuracy: 82.33%
# Epoch 71. Training loss: 0.336. Validation loss: 0.335. Validation accuracy: 82.33%
# Epoch 72. Training loss: 0.336. Validation loss: 0.335. Validation accuracy: 82.33%
# Epoch 73. Training loss: 0.335. Validation loss: 0.334. Validation accuracy: 82.33%
# Epoch 74. Training loss: 0.335. Validation loss: 0.334. Validation accuracy: 82.55%
# Epoch 75. Training loss: 0.334. Validation loss: 0.334. Validation accuracy: 82.55%
# Epoch 76. Training loss: 0.334. Validation loss: 0.333. Validation accuracy: 82.55%
# Epoch 77. Training loss: 0.334. Validation loss: 0.333. Validation accuracy: 82.55%
# Epoch 78. Training loss: 0.333. Validation loss: 0.333. Validation accuracy: 82.55%
# Epoch 79. Training loss: 0.333. Validation loss: 0.333. Validation accuracy: 82.77%
# Epoch 80. Training loss: 0.332. Validation loss: 0.332. Validation accuracy: 82.77%
# Epoch 81. Training loss: 0.332. Validation loss: 0.332. Validation accuracy: 83.00%
# Epoch 82. Training loss: 0.332. Validation loss: 0.332. Validation accuracy: 83.00%
# Epoch 83. Training loss: 0.331. Validation loss: 0.332. Validation accuracy: 83.00%
# Epoch 84. Training loss: 0.331. Validation loss: 0.332. Validation accuracy: 83.00%
# Epoch 85. Training loss: 0.331. Validation loss: 0.331. Validation accuracy: 83.00%
# Epoch 86. Training loss: 0.330. Validation loss: 0.331. Validation accuracy: 83.00%
# Epoch 87. Training loss: 0.330. Validation loss: 0.331. Validation accuracy: 83.00%
# Epoch 88. Training loss: 0.330. Validation loss: 0.331. Validation accuracy: 83.00%
# Epoch 89. Training loss: 0.329. Validation loss: 0.331. Validation accuracy: 83.00%
# Epoch 90. Training loss: 0.329. Validation loss: 0.331. Validation accuracy: 82.77%
# Epoch 91. Training loss: 0.329. Validation loss: 0.330. Validation accuracy: 83.00%
# Epoch 92. Training loss: 0.328. Validation loss: 0.330. Validation accuracy: 82.77%
# Epoch 93. Training loss: 0.328. Validation loss: 0.330. Validation accuracy: 82.77%
# Epoch 94. Training loss: 0.328. Validation loss: 0.330. Validation accuracy: 83.00%
# Epoch 95. Training loss: 0.328. Validation loss: 0.330. Validation accuracy: 83.00%
# Epoch 96. Training loss: 0.327. Validation loss: 0.330. Validation accuracy: 83.00%
# Epoch 97. Training loss: 0.327. Validation loss: 0.330. Validation accuracy: 83.00%
# Epoch 98. Training loss: 0.327. Validation loss: 0.329. Validation accuracy: 83.00%
# Epoch 99. Training loss: 0.326. Validation loss: 0.329. Validation accuracy: 83.22%
# Epoch 100. Training loss: 0.326. Validation loss: 0.329. Validation accuracy: 83.22%
# End of training.

# %% [markdown]
# ## Test the model

# %%
# Load the test data in batches
test_data = Batch_data_reader('Test')
#Obtain the test accuracy
for inputs_batch, targets_batch in test_data:
    test_accuracy = sess.run([accuracy],
                     feed_dict={inputs: inputs_batch, targets: targets_batch})

#convert value of first position to get the percentage of accuracy
test_accuracy_percent = test_accuracy[0] * 100.

# Print accuracy
print('Test accuracy: '+'{0:.2f}'.format(test_accuracy_percent)+'%')
# Out:
# Test accuracy: 82.37%
